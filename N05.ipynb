# %%
import pandas as pd
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
#import cv2
#from astral import LocationInfo
#from astral.sun import sun
#from datetime import datetime
#import pytz

# %%
def plot_n_images(df, n):
    for i in range(0,n):
        jpg_path=f"Orinoquia_Carma_Traps/orinoquia_camera_traps_images/public/{df.file_name[i]}"
        img = Image.open(jpg_path)
        # Plot it
        print(i)
        print(df.has_animal[i])
        #print(df.category_id[i])
        #print(df.seq_num_frames[i])

        plt.imshow(img)
        plt.axis("off")  # Hide axes
        plt.show()

# %%
df=pd.read_csv("N05_balanced_relabeled.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 308 entries, 0 to 307
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Unnamed: 0.1    308 non-null    int64
#  1   Unnamed: 0      308 non-null    int64
#  2   id              308 non-null    object
#  3   datetime        308 non-null    object
#  4   file_name       308 non-null    object
#  5   seq_id          308 non-null    object
#  6   frame_num       308 non-null    int64
#  7   seq_num_frames  308 non-null    int64
#  8   location        308 non-null    object
#  9   category_id     308 non-null    int64
#  10  has_animal      308 non-null    int64
#  11  species         308 non-null    object
# dtypes: int64(6), object(6)
# memory usage: 29.0+ KB

# %%
df_locations=df.groupby(["location","has_animal"]).size().reset_index(name="count")
df_pivot = df_locations.pivot(index='location', columns='has_animal', values='count').fillna(0)

df_pivot['total'] = df_pivot[0] + df_pivot[1]
df_pivot = df_pivot.sort_values('total', ascending=False).drop(columns='total')

# %%
df_pivot.plot(kind='bar', stacked=True, color=["#E9511F", "#49AEF7"], figsize=(12, 6))
# Customize
plt.title("Observations by Location and Animal Presence")
plt.xlabel("Location")
plt.ylabel("Count")
plt.legend(["No Animal (0)", "Has Animal (1)"], title="Animal Presence")
plt.tight_layout()
plt.show()

# %%
df=df.drop("species", axis=1)

# %%
plot_n_images(df,5)
# Out:
# 0
# 1
# 1
# 1
# 2
# 1
# 3
# 1
# 4
# 0

# %%
image_data = []
labels = []
# Replace with your own dataframe or image/label loading logic
for i in range(len(df)):
    if(i%1000==0):
        print(i)
    img_path = f"Orinoquia_Carma_Traps/orinoquia_camera_traps_images/public/{df.file_name[i]}"
    img = Image.open(img_path).convert("L")  # Convert to grayscale for simplicity
    img_resized = img.resize((150, 150))       # Resize for consistency
    img_array = np.array(img_resized).flatten()  # Flatten to 1D vector
    image_data.append(img_array)
    labels.append(df.has_animal[i])

X = np.array(image_data)
y = np.array(labels)
# Out:
# 0

# %% [markdown]
# ## PCP

# %%
from pcp import PCP

# %%
X_rank = np.linalg.matrix_rank(X)
print(X_rank)
# Out:
# 308

# %%
pcp_alm = PCP()
mu = pcp_alm.default_mu(X)

# %%
L_pcp, S_pcp = pcp_alm.decompose(X, mu, tol=1e-5, max_iter=500)

# %%
f'intrisic rank: {np.linalg.matrix_rank(L_pcp)}, original rank: {np.linalg.matrix_rank(X)}, fraction of outliers: {(S_pcp != 0).mean():.3f}'
# Out:
# 'intrisic rank: 133, original rank: 308, fraction of outliers: 0.709'

# %%
for i in range(0,5):
    index=i
    img_vector = X[index].reshape(1, -1)
    img_X=img_vector.reshape(150, 150)
    
    img_vector = L_pcp[index].reshape(1, -1)
    img_L=img_vector.reshape(150, 150)
    
    img_vector = S_pcp[index].reshape(1, -1)
    img_S=img_vector.reshape(150, 150)
    
    
    print(df.has_animal[i])
    fig, axs = plt.subplots(1, 3, figsize=(12, 4))  # 1 row, 3 columns
    
    axs[0].imshow(img_X, cmap='gray')
    axs[0].set_title('Image 1')
    axs[0].axis('off')
    
    axs[1].imshow(img_L, cmap='gray')
    axs[1].set_title('Image 2')
    axs[1].axis('off')
    
    axs[2].imshow(img_S, cmap='gray')
    axs[2].set_title('Image 3')
    axs[2].axis('off')
    
    plt.tight_layout()
    plt.show()
# Out:
# 1
# 1
# 1
# 1
# 0

# %% [markdown]
# ## Stable PCP

# %%
#from pcp import StablePCP

# %%
# X_rank = np.linalg.matrix_rank(X)
# print(X_rank)

# %%
# st_pcp = StablePCP()
# mu = st_pcp.default_mu(X, sigma=10)
# L_st_pcp, S_st_pcp = st_pcp.decompose(X, mu, tol=1e-5, max_iter=500)

# %%
# f'intrisic rank: {np.linalg.matrix_rank(L_st_pcp)}, original rank: {np.linalg.matrix_rank(X)}, fraction of outliers: {(S_st_pcp != 0).mean():.3f}'

# %%
# for i in range(5,15):
#     index=i
#     img_vector = X[index].reshape(1, -1)
#     img_X=img_vector.reshape(150, 150)
    
#     img_vector = L_st_pcp[index].reshape(1, -1)
#     img_L=img_vector.reshape(150, 150)
    
#     img_vector = S_st_pcp[index].reshape(1, -1)
#     img_S=img_vector.reshape(150, 150)
    
    
#     print(df.has_animal[i])
#     print(df.datetime[i])
#     fig, axs = plt.subplots(1, 3, figsize=(12, 4))  # 1 row, 3 columns
    
#     axs[0].imshow(img_X, cmap='gray')
#     axs[0].set_title('Image 1')
#     axs[0].axis('off')
    
#     axs[1].imshow(img_L, cmap='gray')
#     axs[1].set_title('Image 2')
#     axs[1].axis('off')
    
#     axs[2].imshow(img_S, cmap='gray')
#     axs[2].set_title('Image 3')
#     axs[2].axis('off')
    
#     plt.tight_layout()
#     plt.show()

# %%
from sklearn.svm import LinearSVC
from sklearn import svm
from sklearn.model_selection import train_test_split
from sklearn import metrics
from sklearn.model_selection import GridSearchCV

state=109
# Split dataset into training set and test set

# %% [markdown]
# ### Lin SVC  on S from PCP

# %%
X_train, X_test, y_train, y_test = train_test_split(S_pcp, y, test_size=0.3,random_state=state) # 70% training and 30% test

# %%
clf=LinearSVC()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("F1:",metrics.f1_score(y_test, y_pred))
print("AUC:", metrics.roc_auc_score(y_test,y_pred))
print(clf.get_params())
# Out:
# Accuracy: 0.7311827956989247
# F1: 0.7933884297520661
# AUC: 0.7096774193548387
# {'C': 1.0, 'class_weight': None, 'dual': 'auto', 'fit_intercept': True, 'intercept_scaling': 1, 'loss': 'squared_hinge', 'max_iter': 1000, 'multi_class': 'ovr', 'penalty': 'l2', 'random_state': None, 'tol': 0.0001, 'verbose': 0}

# %% [markdown]
# ## SVC GridSearch on S from PCP

# %%
X_train, X_test, y_train, y_test = train_test_split(S_pcp, y, test_size=0.3,random_state=state) # 70% training and 30% test

# %%
param_grid = [
  {'C': [1, 10, 100, 1000], 'kernel': ['linear']},
  {'C': [1, 10, 100, 1000], 'gamma': [0.001, 0.0001], 'kernel': ['rbf']},
 ]

# %%
SVC=svm.SVC()
clf = GridSearchCV(SVC, param_grid, verbose=2)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] END .................................C=1, kernel=linear; total time=   1.9s
# [CV] END .................................C=1, kernel=linear; total time=   1.9s
# [CV] END .................................C=1, kernel=linear; total time=   1.9s
# [CV] END .................................C=1, kernel=linear; total time=   1.9s
# [CV] END .................................C=1, kernel=linear; total time=   1.9s
# [CV] END ................................C=10, kernel=linear; total time=   1.9s
# [CV] END ................................C=10, kernel=linear; total time=   1.9s
# [CV] END ................................C=10, kernel=linear; total time=   1.9s
# [CV] END ................................C=10, kernel=linear; total time=   1.9s
# [CV] END ................................C=10, kernel=linear; total time=   2.0s
# [CV] END ...............................C=100, kernel=linear; total time=   2.1s
# [CV] END ...............................C=100, kernel=linear; total time=   1.9s
# [CV] END ...............................C=100, kernel=linear; total time=   1.9s
# [CV] END ...............................C=100, kernel=linear; total time=   1.9s
# [CV] END ...............................C=100, kernel=linear; total time=   2.0s
# [CV] END ..............................C=1000, kernel=linear; total time=   1.9s
# [CV] END ..............................C=1000, kernel=linear; total time=   2.0s
# [CV] END ..............................C=1000, kernel=linear; total time=   2.0s
# [CV] END ..............................C=1000, kernel=linear; total time=   1.9s
# [CV] END ..............................C=1000, kernel=linear; total time=   1.9s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   2.3s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   2.3s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   2.3s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   2.3s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   2.3s
# [CV] END ......................C=1, gamma=0.0001, kernel=rbf; total time=   2.3s
# [CV] END ......................C=1, gamma=0.0001, kernel=rbf; total time=   2.3s
# [CV] END ......................C=1, gamma=0.0001, kernel=rbf; total time=   2.3s
# [CV] END ......................C=1, gamma=0.0001, kernel=rbf; total time=   2.2s
# [CV] END ......................C=1, gamma=0.0001, kernel=rbf; total time=   2.3s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   2.3s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   2.3s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   2.3s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   2.3s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   2.5s
# [CV] END .....................C=10, gamma=0.0001, kernel=rbf; total time=   2.4s
# [CV] END .....................C=10, gamma=0.0001, kernel=rbf; total time=   2.3s
# [CV] END .....................C=10, gamma=0.0001, kernel=rbf; total time=   2.3s
# [CV] END .....................C=10, gamma=0.0001, kernel=rbf; total time=   2.4s
# [CV] END .....................C=10, gamma=0.0001, kernel=rbf; total time=   2.6s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   2.3s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   2.4s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   2.3s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   2.3s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   2.3s
# [CV] END ....................C=100, gamma=0.0001, kernel=rbf; total time=   2.4s
# [CV] END ....................C=100, gamma=0.0001, kernel=rbf; total time=   2.4s
# [CV] END ....................C=100, gamma=0.0001, kernel=rbf; total time=   2.3s
# [CV] END ....................C=100, gamma=0.0001, kernel=rbf; total time=   2.4s
# [CV] END ....................C=100, gamma=0.0001, kernel=rbf; total time=   2.5s
# [CV] END ....................C=1000, gamma=0.001, kernel=rbf; total time=   2.3s
# [CV] END ....................C=1000, gamma=0.001, kernel=rbf; total time=   2.5s
# [CV] END ....................C=1000, gamma=0.001, kernel=rbf; total time=   2.4s
# [CV] END ....................C=1000, gamma=0.001, kernel=rbf; total time=   2.3s
# [CV] END ....................C=1000, gamma=0.001, kernel=rbf; total time=   2.4s
# [CV] END ...................C=1000, gamma=0.0001, kernel=rbf; total time=   2.3s
# [CV] END ...................C=1000, gamma=0.0001, kernel=rbf; total time=   2.5s
# [CV] END ...................C=1000, gamma=0.0001, kernel=rbf; total time=   2.3s
# [CV] END ...................C=1000, gamma=0.0001, kernel=rbf; total time=   2.3s
# [CV] END ...................C=1000, gamma=0.0001, kernel=rbf; total time=   2.7s

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("F1:",metrics.f1_score(y_test, y_pred))
print("AUC:", metrics.roc_auc_score(y_test,y_pred))
print("Best parameters found:", clf.best_params_)
# Out:
# Accuracy: 0.6666666666666666
# F1: 0.8
# AUC: 0.5
# Best parameters found: {'C': 1, 'gamma': 0.001, 'kernel': 'rbf'}

# %%
from sklearn.metrics import confusion_matrix
    
cm = confusion_matrix(y_test, y_pred)

# %%
cm = confusion_matrix(y_test, y_pred)
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
    
for i in range(len(cm)):
    for j in range(len(cm)):
        plt.text(j, i, str(cm[i][j]), ha='center', va='center')
    
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# ## RF GridSearch on S from PCP

# %%
X_train, X_test, y_train, y_test = train_test_split(S_pcp, y, test_size=0.3,random_state=state) # 70% training and 30% test

# %%
from sklearn.ensemble import RandomForestClassifier
param_grid = {
    'n_estimators': [100, 200, 500],
    'max_depth': [5, 10, 15],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}
rf_model = RandomForestClassifier(random_state=42)
grid_search = GridSearchCV(estimator=rf_model, param_grid=param_grid, cv=3, scoring='accuracy', verbose=2)
grid_search.fit(X_train, y_train)

best_params = grid_search.best_params_
best_model = grid_search.best_estimator_

accuracy = best_model.score(X_test, y_test)
# Out:
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.1s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.1s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.1s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   2.7s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   2.8s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   2.8s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   2.6s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   3.0s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   2.8s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.6s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   1.2s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   1.1s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   1.1s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   2.7s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   3.1s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   2.7s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.1s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.1s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   2.5s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   2.6s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   2.5s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   2.6s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   2.6s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   2.5s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   2.5s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   2.6s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   2.7s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.9s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   2.4s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   3.1s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   2.5s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.9s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.9s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.9s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   2.5s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   2.4s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   2.4s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.9s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   2.7s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   2.5s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   2.4s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.2s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.3s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.2s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   3.2s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   3.2s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   3.1s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.6s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.7s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.6s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.3s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.3s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.4s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   3.2s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   3.3s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   3.7s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.6s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.6s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   1.3s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   1.3s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   1.5s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   3.2s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   3.2s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   3.0s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.1s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.3s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.2s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   2.9s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   3.3s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   3.3s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.7s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.1s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.2s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.2s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   3.0s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   3.1s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   2.8s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.7s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.6s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   1.1s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   1.2s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   1.1s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   3.0s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   3.0s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   3.0s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.9s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.0s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.0s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   2.7s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   2.6s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   2.8s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.0s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.0s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.0s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   2.5s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   2.8s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   2.5s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.9s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.0s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.0s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   2.5s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   2.6s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   2.8s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.2s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.3s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.2s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   3.4s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   3.5s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   3.3s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.6s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.6s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.6s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.3s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.4s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.2s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   3.2s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   3.4s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   3.3s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.6s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.6s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   1.5s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   1.5s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   1.5s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   3.7s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   4.7s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   3.5s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.7s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.7s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.3s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.9s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.5s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   3.1s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   3.2s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   3.0s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.6s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.1s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.2s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.2s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   4.1s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   3.1s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   3.0s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   1.1s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   1.2s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   1.1s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   2.8s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   2.9s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   2.9s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.0s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.0s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.0s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   2.5s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   2.6s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   2.7s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.9s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.0s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   1.0s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   2.5s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   2.5s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   2.6s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.9s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.0s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.9s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   2.5s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   2.5s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   2.5s

# %%
best_params = grid_search.best_params_
best_model = grid_search.best_estimator_
accuracy = best_model.score(X_test, y_test)
y_pred = best_model.predict(X_test)
print(accuracy)
# Out:
# 0.7526881720430108

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("F1:",metrics.f1_score(y_test, y_pred))
print("AUC:", metrics.roc_auc_score(y_test,y_pred))
print(best_params)
# Out:
# Accuracy: 0.7526881720430108
# F1: 0.8345323741007195
# AUC: 0.6612903225806451
# {'max_depth': 10, 'min_samples_leaf': 1, 'min_samples_split': 5, 'n_estimators': 200}

# %%
cm = confusion_matrix(y_test, y_pred)
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
    
for i in range(len(cm)):
    for j in range(len(cm)):
        plt.text(j, i, str(cm[i][j]), ha='center', va='center')
    
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# #### Test this model on A03

# %%
# df=pd.read_csv("A03_balanced.csv")
# df=df.drop("species", axis=1)
# image_data = []
# labels = []
# # Replace with your own dataframe or image/label loading logic
# for i in range(len(df)):
#     if(i%1000==0):
#         print(i)
#     img_path = f"Orinoquia_Carma_Traps/orinoquia_camera_traps_images/public/{df.file_name[i]}"
#     img = Image.open(img_path).convert("L")  # Convert to grayscale for simplicity
#     img_resized = img.resize((150, 150))       # Resize for consistency
#     img_array = np.array(img_resized).flatten()  # Flatten to 1D vector
#     image_data.append(img_array)
#     labels.append(df.has_animal[i])

# X = np.array(image_data)
# y = np.array(labels)

# %%
# pcp_alm = PCP()
# mu = pcp_alm.default_mu(X)
# L_pcp, S_pcp = pcp_alm.decompose(X, mu, tol=1e-5, max_iter=500)

# %%
# accuracy = best_model.score(S_pcp, y)
# print(accuracy)

# %%
# y_pred = best_model.predict(X_test)
# cm = confusion_matrix(y_test, y_pred)
# plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
# plt.title('Confusion Matrix')
# plt.colorbar()
    
# for i in range(len(cm)):
#     for j in range(len(cm)):
#         plt.text(j, i, str(cm[i][j]), ha='center', va='center')
    
# plt.xlabel('Predicted Label')
# plt.ylabel('True Label')
# plt.show()

# %% [markdown]
# ## Lin SVC on S from stable PCP

# %%
# X_train, X_test, y_train, y_test = train_test_split(S_st_pcp, y, test_size=0.3,random_state=19) # 70% training and 30% test

# %%
# clf=LinearSVC()
# clf.fit(X_train, y_train)
# y_pred = clf.predict(X_test)

# %%
#print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

# %% [markdown]
# ## SVC GridSearch on S from stable PCP

# %%
#X_train, X_test, y_train, y_test = train_test_split(S_pcp, y, test_size=0.3,random_state=109) # 70% training and 30% test

# %%
# param_grid = [
#   {'C': [1, 10, 100, 1000], 'kernel': ['linear']},
#   {'C': [1, 10, 100, 1000], 'gamma': [0.001, 0.0001], 'kernel': ['rbf']},
#  ]

# %%
# SVC=svm.SVC()
# clf = GridSearchCV(SVC, param_grid, verbose=2)
# clf.fit(X_train, y_train)
# y_pred = clf.predict(X_test)

# %%
#print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

# %%
# from sklearn.metrics import confusion_matrix
    
# cm = confusion_matrix(y_test, y_pred)

# %%
# import matplotlib.pyplot as plt
    
# plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
# plt.title('Confusion Matrix')
# plt.colorbar()
    
# for i in range(len(cm)):
#     for j in range(len(cm)):
#         plt.text(j, i, str(cm[i][j]), ha='center', va='center')
    
# plt.xlabel('Predicted Label')
# plt.ylabel('True Label')
# plt.show()

# %% [markdown]
# ## LinearSVC on images

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state=state) # 70% training and 30% test

clf = LinearSVC()
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
# Out:
# E:\camra trap identification\venv\Lib\site-packages\sklearn\svm\_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("F1:",metrics.f1_score(y_test, y_pred))
print("AUC:", metrics.roc_auc_score(y_test,y_pred))
# Out:
# Accuracy: 0.6881720430107527
# F1: 0.7603305785123967
# AUC: 0.6612903225806451

# %%
from sklearn.metrics import confusion_matrix
    
cm = confusion_matrix(y_test, y_pred)

# %%
import matplotlib.pyplot as plt
    
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
    
for i in range(len(cm)):
    for j in range(len(cm)):
        plt.text(j, i, str(cm[i][j]), ha='center', va='center')
    
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# ## SVM gridsearch on image

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state=state) # 70% training and 30% test

# %%
param_grid = [
  {'C': [1, 10, 100, 1000], 'kernel': ['linear']},
  {'C': [1, 10, 100, 1000], 'gamma': [0.001, 0.0001], 'kernel': ['rbf']},
 ]

# %%
SVC=svm.SVC()
clf = GridSearchCV(SVC, param_grid, verbose=2)
clf.fit(X_train, y_train)
y_pred = clf.predict(X_test)
# Out:
# Fitting 5 folds for each of 12 candidates, totalling 60 fits
# [CV] END .................................C=1, kernel=linear; total time=   1.7s
# [CV] END .................................C=1, kernel=linear; total time=   1.8s
# [CV] END .................................C=1, kernel=linear; total time=   1.6s
# [CV] END .................................C=1, kernel=linear; total time=   1.7s
# [CV] END .................................C=1, kernel=linear; total time=   1.7s
# [CV] END ................................C=10, kernel=linear; total time=   1.7s
# [CV] END ................................C=10, kernel=linear; total time=   1.9s
# [CV] END ................................C=10, kernel=linear; total time=   1.7s
# [CV] END ................................C=10, kernel=linear; total time=   1.7s
# [CV] END ................................C=10, kernel=linear; total time=   1.7s
# [CV] END ...............................C=100, kernel=linear; total time=   1.8s
# [CV] END ...............................C=100, kernel=linear; total time=   1.8s
# [CV] END ...............................C=100, kernel=linear; total time=   1.7s
# [CV] END ...............................C=100, kernel=linear; total time=   1.9s
# [CV] END ...............................C=100, kernel=linear; total time=   1.7s
# [CV] END ..............................C=1000, kernel=linear; total time=   1.8s
# [CV] END ..............................C=1000, kernel=linear; total time=   1.8s
# [CV] END ..............................C=1000, kernel=linear; total time=   1.7s
# [CV] END ..............................C=1000, kernel=linear; total time=   1.8s
# [CV] END ..............................C=1000, kernel=linear; total time=   1.7s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   2.5s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   2.5s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   2.4s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   2.4s
# [CV] END .......................C=1, gamma=0.001, kernel=rbf; total time=   2.3s
# [CV] END ......................C=1, gamma=0.0001, kernel=rbf; total time=   2.4s
# [CV] END ......................C=1, gamma=0.0001, kernel=rbf; total time=   2.7s
# [CV] END ......................C=1, gamma=0.0001, kernel=rbf; total time=   2.3s
# [CV] END ......................C=1, gamma=0.0001, kernel=rbf; total time=   2.3s
# [CV] END ......................C=1, gamma=0.0001, kernel=rbf; total time=   2.3s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   2.5s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   2.3s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   2.4s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   2.3s
# [CV] END ......................C=10, gamma=0.001, kernel=rbf; total time=   2.3s
# [CV] END .....................C=10, gamma=0.0001, kernel=rbf; total time=   2.3s
# [CV] END .....................C=10, gamma=0.0001, kernel=rbf; total time=   2.4s
# [CV] END .....................C=10, gamma=0.0001, kernel=rbf; total time=   2.4s
# [CV] END .....................C=10, gamma=0.0001, kernel=rbf; total time=   2.4s
# [CV] END .....................C=10, gamma=0.0001, kernel=rbf; total time=   2.4s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   2.5s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   2.3s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   2.3s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   2.3s
# [CV] END .....................C=100, gamma=0.001, kernel=rbf; total time=   2.3s
# [CV] END ....................C=100, gamma=0.0001, kernel=rbf; total time=   2.3s
# [CV] END ....................C=100, gamma=0.0001, kernel=rbf; total time=   2.3s
# [CV] END ....................C=100, gamma=0.0001, kernel=rbf; total time=   2.3s
# [CV] END ....................C=100, gamma=0.0001, kernel=rbf; total time=   2.3s
# [CV] END ....................C=100, gamma=0.0001, kernel=rbf; total time=   2.3s
# [CV] END ....................C=1000, gamma=0.001, kernel=rbf; total time=   2.3s
# [CV] END ....................C=1000, gamma=0.001, kernel=rbf; total time=   2.3s
# [CV] END ....................C=1000, gamma=0.001, kernel=rbf; total time=   2.5s
# [CV] END ....................C=1000, gamma=0.001, kernel=rbf; total time=   2.3s
# [CV] END ....................C=1000, gamma=0.001, kernel=rbf; total time=   2.4s
# [CV] END ...................C=1000, gamma=0.0001, kernel=rbf; total time=   2.3s
# [CV] END ...................C=1000, gamma=0.0001, kernel=rbf; total time=   2.3s
# [CV] END ...................C=1000, gamma=0.0001, kernel=rbf; total time=   2.3s
# [CV] END ...................C=1000, gamma=0.0001, kernel=rbf; total time=   2.3s
# [CV] END ...................C=1000, gamma=0.0001, kernel=rbf; total time=   2.3s

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("F1:",metrics.f1_score(y_test, y_pred))
print("AUC:", metrics.roc_auc_score(y_test,y_pred))
print("Best parameters found:", clf.best_params_)
# Out:
# Accuracy: 0.7204301075268817
# F1: 0.7833333333333333
# AUC: 0.7016129032258065
# Best parameters found: {'C': 1, 'kernel': 'linear'}

# %%
from sklearn.metrics import confusion_matrix
    
cm = confusion_matrix(y_test, y_pred)

# %%
import matplotlib.pyplot as plt
    
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
    
for i in range(len(cm)):
    for j in range(len(cm)):
        plt.text(j, i, str(cm[i][j]), ha='center', va='center')
    
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()

# %% [markdown]
# ## RF GridSearch on images

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3,random_state=state) # 70% training and 30% test

# %%
from sklearn.ensemble import RandomForestClassifier
param_grid = {
    'n_estimators': [100, 200, 500],
    'max_depth': [5, 10, 15],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}
rf_model = RandomForestClassifier(random_state=42)
grid_search = GridSearchCV(estimator=rf_model, param_grid=param_grid, cv=3, scoring='accuracy', verbose=2)
grid_search.fit(X_train, y_train)

best_params = grid_search.best_params_
best_model = grid_search.best_estimator_

accuracy = best_model.score(X_test, y_test)
# Out:
# Fitting 3 folds for each of 81 candidates, totalling 243 fits
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   0.9s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   2.6s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   2.5s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   2.6s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.9s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   0.9s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   2.8s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   2.5s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   2.6s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.9s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.9s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   0.9s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   2.6s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   2.4s
# [CV] END max_depth=5, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   2.5s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.9s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.9s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   3.3s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   2.5s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   2.5s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.1s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   2.4s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   2.3s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   2.4s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.9s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.8s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.9s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   2.4s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   2.2s
# [CV] END max_depth=5, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   2.4s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   1.0s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.9s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.9s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   2.4s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   2.2s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   2.4s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.9s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.8s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.8s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   2.3s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   2.2s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   2.3s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.8s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.8s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.9s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   2.3s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   2.5s
# [CV] END max_depth=5, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   2.3s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.1s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.0s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.2s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   2.9s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   2.6s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   3.0s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.0s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.0s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.1s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   2.8s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   2.7s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   3.0s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   1.2s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   1.0s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   1.1s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   2.7s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   2.5s
# [CV] END max_depth=10, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   3.0s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.0s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   0.9s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.0s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   2.6s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   2.6s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   2.7s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.0s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.0s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.2s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   2.6s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   2.6s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   2.7s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   1.0s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   1.0s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   1.1s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   2.6s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   2.5s
# [CV] END max_depth=10, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   2.8s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.9s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.9s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   2.3s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   2.4s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   2.2s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.3s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.8s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   2.2s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   2.1s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   2.3s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.9s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   1.0s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.9s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   2.3s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   2.1s
# [CV] END max_depth=10, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   2.3s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=2, n_estimators=100; total time=   0.6s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.1s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.0s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=2, n_estimators=200; total time=   1.1s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   3.0s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   3.2s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=2, n_estimators=500; total time=   3.1s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.0s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.0s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=5, n_estimators=200; total time=   1.1s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   2.8s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   2.6s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=5, n_estimators=500; total time=   3.0s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   1.0s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   1.0s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=10, n_estimators=200; total time=   1.0s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   2.6s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   2.5s
# [CV] END max_depth=15, min_samples_leaf=1, min_samples_split=10, n_estimators=500; total time=   2.9s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=2, n_estimators=100; total time=   0.5s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.0s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.0s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=2, n_estimators=200; total time=   1.1s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   2.8s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   2.5s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=2, n_estimators=500; total time=   2.7s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=5, n_estimators=100; total time=   0.5s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.0s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.0s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=5, n_estimators=200; total time=   1.1s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   2.7s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   2.5s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=5, n_estimators=500; total time=   2.8s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.9s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   0.9s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=10, n_estimators=200; total time=   1.0s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   2.5s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   2.4s
# [CV] END max_depth=15, min_samples_leaf=2, min_samples_split=10, n_estimators=500; total time=   2.5s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=2, n_estimators=100; total time=   0.4s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.8s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.9s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=2, n_estimators=200; total time=   0.9s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   2.2s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   2.2s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=2, n_estimators=500; total time=   2.3s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=5, n_estimators=100; total time=   0.4s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.8s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.8s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=5, n_estimators=200; total time=   0.9s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   2.3s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   2.1s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=5, n_estimators=500; total time=   2.2s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.5s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=10, n_estimators=100; total time=   0.4s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.9s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.8s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=10, n_estimators=200; total time=   0.8s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   2.2s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   2.2s
# [CV] END max_depth=15, min_samples_leaf=4, min_samples_split=10, n_estimators=500; total time=   2.4s

# %%
best_params = grid_search.best_params_
best_model = grid_search.best_estimator_
y_pred = best_model.predict(X_test)

accuracy = best_model.score(X_test, y_test)

print(accuracy)
# Out:
# 0.6666666666666666

# %%
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
print("F1:",metrics.f1_score(y_test, y_pred))
print("AUC:", metrics.roc_auc_score(y_test,y_pred))
print(best_params)
# Out:
# Accuracy: 0.6666666666666666
# F1: 0.7669172932330827
# AUC: 0.588709677419355
# {'max_depth': 5, 'min_samples_leaf': 1, 'min_samples_split': 2, 'n_estimators': 200}

# %%
cm = confusion_matrix(y_test, y_pred)
plt.imshow(cm, interpolation='nearest', cmap=plt.cm.Blues)
plt.title('Confusion Matrix')
plt.colorbar()
    
for i in range(len(cm)):
    for j in range(len(cm)):
        plt.text(j, i, str(cm[i][j]), ha='center', va='center')
    
plt.xlabel('Predicted Label')
plt.ylabel('True Label')
plt.show()
